# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Remember and Check Notes:
# >As long as we haven't reached the final output layer, we should use the 'relu' activation function.
#
# > For Binary classification: `Sigmoid` activation function,
#
# > For Multi-class classification: `Softmax` activation function.

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import image_dataset_from_directory

# %%
#Preprocessing the training set
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2, 
    horizontal_flip=True
)
training_dataset= train_datagen.flow_from_directory(
                '/kaggle/input/cnn-cats-and-dogs/Section 40 - Convolutional Neural Networks (CNN)/dataset/training_set',
                target_size=(64,64),
                batch_size=32,
                class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %%
#Preprocessing the test set
test_datagen=ImageDataGenerator(rescale=1./255)
test_dataset= test_datagen.flow_from_directory(
            '/kaggle/input/cnn-cats-and-dogs/Section 40 - Convolutional Neural Networks (CNN)/dataset/test_set',
            target_size=(64,64),
            batch_size=32,
            class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn=tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation= 'relu', input_shape=(64,64,3)))
#filters= randomly choosen no. of filters
#kernel_size = dimensions of filter(3=3x3)
#input_shape=(64->given above, 3-> RGB color, 1-> Black&White colour)

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2),
    strides=2,
    data_format=None,
    name=None,
))
# pool_size= When we create pooled feature map from the feature map, dimensions of the square,
#which gives us features from the feature map, is the pool_size.
#strides= steps-taken by the pool_matrix in the feature_matrix while forming the pooled feature_matrix.

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation= 'relu'))
cnn.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2),
    strides=2,
    data_format=None,
    name=None,
))
#Input_shape was defined just for the first layer to connect the input_layer to the first convolutional network

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten(
    data_format=None
))

# %% [markdown]
# ### Step 4 - Full Connection

# %%
#Implementing a fully connected ANN from hereon:
cnn.add(tf.keras.layers.Dense(units=128,
                             activation='relu',
                             ))
#units= No. of neurons, usually higher the number, better the accuracy, hence we are using 128.

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1,
                             activation='sigmoid'
                             ))
# We are using binary classification, hence 1 neuron for either 'cat' or 'dog'.

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x=training_dataset,validation_data=test_dataset,epochs=25)
# Out:
# Epoch 1/25
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 103s 395ms/step - accuracy: 0.5239 - loss: 0.6929 - val_accuracy: 0.6115 - val_loss: 0.6536
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 101s 236ms/step - accuracy: 0.6337 - loss: 0.6370 - val_accuracy: 0.7040 - val_loss: 0.5801
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 241ms/step - accuracy: 0.6983 - loss: 0.5643 - val_accuracy: 0.7275 - val_loss: 0.5451
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 61s 241ms/step - accuracy: 0.7528 - loss: 0.5066 - val_accuracy: 0.7295 - val_loss: 0.5382
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 238ms/step - accuracy: 0.7809 - loss: 0.4639 - val_accuracy: 0.7800 - val_loss: 0.4948
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 237ms/step - accuracy: 0.8007 - loss: 0.4211 - val_accuracy: 0.7860 - val_loss: 0.4645
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 240ms/step - accuracy: 0.8273 - loss: 0.3891 - val_accuracy: 0.7865 - val_loss: 0.4605
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 238ms/step - accuracy: 0.8475 - loss: 0.3573 - val_accuracy: 0.7820 - val_loss: 0.4703
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 237ms/step - accuracy: 0.8638 - loss: 0.3170 - val_accuracy: 0.7685 - val_loss: 0.4994
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 239ms/step - accuracy: 0.8834 - loss: 0.2800 - val_accuracy: 0.7785 - val_loss: 0.5280
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 236ms/step - accuracy: 0.9046 - loss: 0.2323 - val_accuracy: 0.8000 - val_loss: 0.5317
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 237ms/step - accuracy: 0.9222 - loss: 0.1939 - val_accuracy: 0.7945 - val_loss: 0.5585
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 237ms/step - accuracy: 0.9316 - loss: 0.1712 - val_accuracy: 0.8005 - val_loss: 0.6381
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 235ms/step - accuracy: 0.9514 - loss: 0.1231 - val_accuracy: 0.7940 - val_loss: 0.6684
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 236ms/step - accuracy: 0.9678 - loss: 0.0902 - val_accuracy: 0.7865 - val_loss: 0.8315
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 238ms/step - accuracy: 0.9688 - loss: 0.0868 - val_accuracy: 0.7930 - val_loss: 0.7541
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 234ms/step - accuracy: 0.9834 - loss: 0.0588 - val_accuracy: 0.7935 - val_loss: 0.8003
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 236ms/step - accuracy: 0.9848 - loss: 0.0450 - val_accuracy: 0.7885 - val_loss: 0.8932
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 240ms/step - accuracy: 0.9873 - loss: 0.0386 - val_accuracy: 0.7955 - val_loss: 0.9025
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 239ms/step - accuracy: 0.9836 - loss: 0.0479 - val_accuracy: 0.7850 - val_loss: 1.0022
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 61s 239ms/step - accuracy: 0.9897 - loss: 0.0350 - val_accuracy: 0.7870 - val_loss: 1.0242
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 237ms/step - accuracy: 0.9949 - loss: 0.0209 - val_accuracy: 0.7945 - val_loss: 1.0808
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 238ms/step - accuracy: 0.9927 - loss: 0.0190 - val_accuracy: 0.7750 - val_loss: 1.2753
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 239ms/step - accuracy: 0.9922 - loss: 0.0222 - val_accuracy: 0.7955 - val_loss: 1.1423
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 239ms/step - accuracy: 0.9906 - loss: 0.0271 - val_accuracy: 0.7890 - val_loss: 1.3238

# %% [markdown]
# ## Part 4 - Making a single prediction

# %% [markdown]
# ### Predict method expects a 2-D array. remember we used [[]] earlier.
# > Hence, we have to convert the image to a 2-D array (PIL image instance into a numpy array).
#
# >Also we trained our cnn model on batches, hence we have to predict this 'single image' in a batch
# as well, although the batch will just contain this single image only. The CNN model recognizes this
# batch as an extra dimension.
#
# >The batch is always the first dimension or axis=0

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/kaggle/input/cnn-cats-and-dogs/Section 40 - Convolutional Neural Networks (CNN)/dataset/single_prediction/cat_or_dog_1.jpg',
                           target_size=(64,64))
test_image=image.img_to_array(test_image) #3-D (dim.,dim.,RGB)
test_image=np.expand_dims(test_image, axis=0) #4-D (batch,dim.,dim.,RGB)
result= cnn.predict(test_image/255.0)
# We normalized the result above, to get the value of test image (RGB values) between 0-1, to
#make it easier for the neural network model to predict on
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %% [markdown]
# ### Explanation for normalizing above by doing: cnn.predict(test_image/255.0)
# Some activation functions, like the sigmoid or tanh functions, saturate when the input values are too large or too small. Normalizing the input data helps in preventing saturation of these activation functions, allowing them to operate in their more linear and effective range.

# %%
test_image
# Out:
# array([[[[ 54.,  58.,   7.],
#          [ 58.,  63.,   9.],
#          [ 64.,  67.,  10.],
#          ...,
#          [136., 144.,  71.],
#          [140., 150.,  77.],
#          [139., 149.,  78.]],
#
#         [[ 48.,  54.,   6.],
#          [ 51.,  58.,   7.],
#          [ 58.,  63.,   9.],
#          ...,
#          [129., 137.,  64.],
#          [139., 149.,  78.],
#          [141., 151.,  80.]],
#
#         [[ 48.,  56.,   7.],
#          [ 48.,  56.,   7.],
#          [ 54.,  61.,  10.],
#          ...,
#          [123., 129.,  65.],
#          [136., 145.,  80.],
#          [140., 149.,  82.]],
#
#         ...,
#
#         [[ 46.,  55.,  12.],
#          [ 42.,  50.,  11.],
#          [ 38.,  49.,   9.],
#          ...,
#          [239., 205., 170.],
#          [235., 209., 186.],
#          [231., 201., 173.]],
#
#         [[ 50.,  57.,  13.],
#          [ 42.,  50.,  11.],
#          [ 44.,  52.,  11.],
#          ...,
#          [234., 200., 163.],
#          [236., 206., 178.],
#          [234., 203., 175.]],
#
#         [[ 53.,  59.,  13.],
#          [ 43.,  51.,  10.],
#          [ 49.,  56.,  12.],
#          ...,
#          [233., 195., 159.],
#          [235., 213., 190.],
#          [233., 206., 179.]]]], dtype=float32)

# %%
result
# Out:
# array([[1.]], dtype=float32)

# %%
training_dataset.class_indices
# Out:
# {'cats': 0, 'dogs': 1}

# %% [markdown]
# #### Result is a 2-D array of dimensions: 1x1. (batch no. x size). hence we use [][] to access the first element.

# %%
if result[0][0]==0:
    prediction= 'cat'
else:
    prediction= 'dog'

# %%
print(prediction)
# Out:
# dog

# %% [markdown]
# #### Predicting for the entire test dataset:

# %%
ans=cnn.predict(test_dataset)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step

# %%
ans
# Out:
# array([[8.2308743e-06],
#        [1.4541250e-04],
#        [1.6004703e-10],
#        ...,
#        [1.6358247e-12],
#        [9.2058319e-15],
#        [9.8086727e-01]], dtype=float32)

# %%
threshold =0.5
predicted_labels = np.where(ans >= threshold, "dog", "cat")

# %%
predicted_labels
# Out:
# array([['cat'],
#        ['cat'],
#        ['cat'],
#        ...,
#        ['cat'],
#        ['cat'],
#        ['dog']], dtype='<U3')
